# %%
# llama index -> Llama Index is another open source framework that also lets us connect with models like OpenAI LLMs, Gemini, Groqand and ollama.
# ! pip install -q -U llama-index
# ! pip install -q -U llama-index-llms-openia
# ! pip install -q -U llama-index-llms-ollama

# %%
import os
from dotenv import load_dotenv
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(
    model = "gpt-3.5-turbo",
    temperature = 0.1
)

response = llm.complete("Machine Learning is")
print(response)
# Out:
# Retrying llama_index.llms.openai.base.OpenAI._chat in 1 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}.
# Retrying llama_index.llms.openai.base.OpenAI._chat in 1.1 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 8
#       4     model = "gpt-3.5-turbo",
#       5     temperature = 0.1
#       6 )
#       7
# ----> 8 response = llm.complete("Machine Learning is")
#       9 print(response)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:413, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     410             _logger.debug(f"Failed to reset active_span_id: {e}")
#     412 try:
# --> 413     result = func(*args, **kwargs)
#     414     if isinstance(result, asyncio.Future):
#     415         # If the result is a Future, wrap it
#     416         new_future = asyncio.ensure_future(result)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/core/llms/callbacks.py:447, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     444     _self.rate_limiter.acquire()
#     446 try:
# --> 447     f_return_val = f(_self, *args, **kwargs)
#     448 except BaseException as e:
#     449     callback_manager.on_event_end(
#     450         CBEventType.LLM,
#     451         payload={EventPayload.EXCEPTION: e},
#     452         event_id=event_id,
#     453     )
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/llms/openai/base.py:429, in OpenAI.complete(self, prompt, formatted, **kwargs)
#     427 else:
#     428     complete_fn = self._complete
# --> 429 return complete_fn(prompt, **kwargs)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/core/base/llms/generic_utils.py:184, in chat_to_completion_decorator.<locals>.wrapper(prompt, **kwargs)
#     181 def wrapper(prompt: str, **kwargs: Any) -> CompletionResponse:
#     182     # normalize input
#     183     messages = prompt_to_messages(prompt)
# --> 184     chat_response = func(messages, **kwargs)
#     185     # normalize output
#     186     return chat_response_to_completion_response(chat_response)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/llms/openai/base.py:115, in llm_retry_decorator.<locals>.wrapper(self, *args, **kwargs)
#     106     return f(self, *args, **kwargs)
#     108 retry = create_retry_decorator(
#     109     max_retries=max_retries,
#     110     random_exponential=True,
#    (...)    113     max_seconds=20,
#     114 )
# --> 115 return retry(f)(self, *args, **kwargs)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/llms/openai/base.py:500, in OpenAI._chat(self, messages, **kwargs)
#     494 message_dicts = to_openai_message_dicts(
#     495     messages,
#     496     model=self.model,
#     497 )
#     499 if self.reuse_client:
# --> 500     response = client.chat.completions.create(
#     501         messages=message_dicts,
#     502         stream=False,
#     503         **self._get_model_kwargs(**kwargs),
#     504     )
#     505 else:
#     506     with client:
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1215, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1168 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1169 def create(
#    1170     self,
#    (...)   1212     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1213 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1214     validate_response_format(response_format)
# -> 1215     return self._post(
#    1216         "/chat/completions",
#    1217         body=maybe_transform(
#    1218             {
#    1219                 "messages": messages,
#    1220                 "model": model,
#    1221                 "audio": audio,
#    1222                 "frequency_penalty": frequency_penalty,
#    1223                 "function_call": function_call,
#    1224                 "functions": functions,
#    1225                 "logit_bias": logit_bias,
#    1226                 "logprobs": logprobs,
#    1227                 "max_completion_tokens": max_completion_tokens,
#    1228                 "max_tokens": max_tokens,
#    1229                 "metadata": metadata,
#    1230                 "modalities": modalities,
#    1231                 "n": n,
#    1232                 "parallel_tool_calls": parallel_tool_calls,
#    1233                 "prediction": prediction,
#    1234                 "presence_penalty": presence_penalty,
#    1235                 "prompt_cache_key": prompt_cache_key,
#    1236                 "prompt_cache_retention": prompt_cache_retention,
#    1237                 "reasoning_effort": reasoning_effort,
#    1238                 "response_format": response_format,
#    1239                 "safety_identifier": safety_identifier,
#    1240                 "seed": seed,
#    1241                 "service_tier": service_tier,
#    1242                 "stop": stop,
#    1243                 "store": store,
#    1244                 "stream": stream,
#    1245                 "stream_options": stream_options,
#    1246                 "temperature": temperature,
#    1247                 "tool_choice": tool_choice,
#    1248                 "tools": tools,
#    1249                 "top_logprobs": top_logprobs,
#    1250                 "top_p": top_p,
#    1251                 "user": user,
#    1252                 "verbosity": verbosity,
#    1253                 "web_search_options": web_search_options,
#    1254             },
#    1255             completion_create_params.CompletionCreateParamsStreaming
#    1256             if stream
#    1257             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1258         ),
#    1259         options=make_request_options(
#    1260             extra_headers=extra_headers,
#    1261             extra_query=extra_query,
#    1262             extra_body=extra_body,
#    1263             timeout=timeout,
#    1264             security={"bearer_auth": True},
#    1265         ),
#    1266         cast_to=ChatCompletion,
#    1267         stream=stream or False,
#    1268         stream_cls=Stream[ChatCompletionChunk],
#    1269     )
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
from llama_index.llms.openai import OpenAI
from llama_index.core.llms import ChatMessage

llm = OpenAI(
    model = "gpt-3.5-turbo",
    temperature = 0.1
)

messages = [
    ChatMessage(
        role = "system", content = "You are a pirate with a colourful personality"
    ),
    ChatMessage(
        role = "user", content = "What is your name?"
    ),
]

response = llm.chat(messages)
print(response)
# Out:
# Retrying llama_index.llms.openai.base.OpenAI._chat in 1 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}.
# Retrying llama_index.llms.openai.base.OpenAI._chat in 1.2 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 18
#      14         role = "user", content = "What is your name?"
#      15     ),
#      16 ]
#      17
# ---> 18 response = llm.chat(messages)
#      19 print(response)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:413, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     410             _logger.debug(f"Failed to reset active_span_id: {e}")
#     412 try:
# --> 413     result = func(*args, **kwargs)
#     414     if isinstance(result, asyncio.Future):
#     415         # If the result is a Future, wrap it
#     416         new_future = asyncio.ensure_future(result)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/core/llms/callbacks.py:181, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     178     _self.rate_limiter.acquire()
#     180 try:
# --> 181     f_return_val = f(_self, messages, **kwargs)
#     182 except BaseException as e:
#     183     callback_manager.on_event_end(
#     184         CBEventType.LLM,
#     185         payload={EventPayload.EXCEPTION: e},
#     186         event_id=event_id,
#     187     )
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/llms/openai/base.py:404, in OpenAI.chat(self, messages, **kwargs)
#     402 else:
#     403     chat_fn = completion_to_chat_decorator(self._complete)
# --> 404 return chat_fn(messages, **kwargs)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/llms/openai/base.py:115, in llm_retry_decorator.<locals>.wrapper(self, *args, **kwargs)
#     106     return f(self, *args, **kwargs)
#     108 retry = create_retry_decorator(
#     109     max_retries=max_retries,
#     110     random_exponential=True,
#    (...)    113     max_seconds=20,
#     114 )
# --> 115 return retry(f)(self, *args, **kwargs)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/llms/openai/base.py:500, in OpenAI._chat(self, messages, **kwargs)
#     494 message_dicts = to_openai_message_dicts(
#     495     messages,
#     496     model=self.model,
#     497 )
#     499 if self.reuse_client:
# --> 500     response = client.chat.completions.create(
#     501         messages=message_dicts,
#     502         stream=False,
#     503         **self._get_model_kwargs(**kwargs),
#     504     )
#     505 else:
#     506     with client:
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1215, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1168 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1169 def create(
#    1170     self,
#    (...)   1212     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1213 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1214     validate_response_format(response_format)
# -> 1215     return self._post(
#    1216         "/chat/completions",
#    1217         body=maybe_transform(
#    1218             {
#    1219                 "messages": messages,
#    1220                 "model": model,
#    1221                 "audio": audio,
#    1222                 "frequency_penalty": frequency_penalty,
#    1223                 "function_call": function_call,
#    1224                 "functions": functions,
#    1225                 "logit_bias": logit_bias,
#    1226                 "logprobs": logprobs,
#    1227                 "max_completion_tokens": max_completion_tokens,
#    1228                 "max_tokens": max_tokens,
#    1229                 "metadata": metadata,
#    1230                 "modalities": modalities,
#    1231                 "n": n,
#    1232                 "parallel_tool_calls": parallel_tool_calls,
#    1233                 "prediction": prediction,
#    1234                 "presence_penalty": presence_penalty,
#    1235                 "prompt_cache_key": prompt_cache_key,
#    1236                 "prompt_cache_retention": prompt_cache_retention,
#    1237                 "reasoning_effort": reasoning_effort,
#    1238                 "response_format": response_format,
#    1239                 "safety_identifier": safety_identifier,
#    1240                 "seed": seed,
#    1241                 "service_tier": service_tier,
#    1242                 "stop": stop,
#    1243                 "store": store,
#    1244                 "stream": stream,
#    1245                 "stream_options": stream_options,
#    1246                 "temperature": temperature,
#    1247                 "tool_choice": tool_choice,
#    1248                 "tools": tools,
#    1249                 "top_logprobs": top_logprobs,
#    1250                 "top_p": top_p,
#    1251                 "user": user,
#    1252                 "verbosity": verbosity,
#    1253                 "web_search_options": web_search_options,
#    1254             },
#    1255             completion_create_params.CompletionCreateParamsStreaming
#    1256             if stream
#    1257             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1258         ),
#    1259         options=make_request_options(
#    1260             extra_headers=extra_headers,
#    1261             extra_query=extra_query,
#    1262             extra_body=extra_body,
#    1263             timeout=timeout,
#    1264             security={"bearer_auth": True},
#    1265         ),
#    1266         cast_to=ChatCompletion,
#    1267         stream=stream or False,
#    1268         stream_cls=Stream[ChatCompletionChunk],
#    1269     )
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
import os
from dotenv import load_dotenv
load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
import nest_asyncio
nest_asyncio.apply()

from llama_index.llms.google_genai import GoogleGenAI

llm = GoogleGenAI(
    model="models/gemini-2.5-flash",
    temperature=0
)

response = llm.complete("Write a poem about a magic backpack")
print(response)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Retrying llama_index.llms.google_genai.base.GoogleGenAI._chat in 1 seconds as it raised ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}.
# Retrying llama_index.llms.google_genai.base.GoogleGenAI._chat in 1.48 seconds as it raised ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}.
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[2], line 11
#       7     model="models/gemini-2.5-flash",
#       8     temperature=0
#       9 )
#      10
# ---> 11 response = llm.complete("Write a poem about a magic backpack")
#      12 print(response)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:413, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     410             _logger.debug(f"Failed to reset active_span_id: {e}")
#     412 try:
# --> 413     result = func(*args, **kwargs)
#     414     if isinstance(result, asyncio.Future):
#     415         # If the result is a Future, wrap it
#     416         new_future = asyncio.ensure_future(result)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/core/llms/callbacks.py:447, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     444     _self.rate_limiter.acquire()
#     446 try:
# --> 447     f_return_val = f(_self, *args, **kwargs)
#     448 except BaseException as e:
#     449     callback_manager.on_event_end(
#     450         CBEventType.LLM,
#     451         payload={EventPayload.EXCEPTION: e},
#     452         event_id=event_id,
#     453     )
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/llms/google_genai/base.py:323, in GoogleGenAI.complete(self, prompt, formatted, **kwargs)
#     318 @llm_completion_callback()
#     319 def complete(
#     320     self, prompt: str, formatted: bool = False, **kwargs: Any
#     321 ) -> CompletionResponse:
#     322     chat_fn = chat_to_completion_decorator(self._chat)
# --> 323     return chat_fn(prompt, **kwargs)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/core/base/llms/generic_utils.py:184, in chat_to_completion_decorator.<locals>.wrapper(prompt, **kwargs)
#     181 def wrapper(prompt: str, **kwargs: Any) -> CompletionResponse:
#     182     # normalize input
#     183     messages = prompt_to_messages(prompt)
# --> 184     chat_response = func(messages, **kwargs)
#     185     # normalize output
#     186     return chat_response_to_completion_response(chat_response)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/llms/google_genai/base.py:113, in llm_retry_decorator.<locals>.wrapper(self, *args, **kwargs)
#     105     return f(self, *args, **kwargs)
#     106 retry = create_retry_decorator(
#     107     max_retries=max_retries,
#     108     random_exponential=True,
#    (...)    111     max_seconds=20,
#     112 )
# --> 113 return retry(f)(self, *args, **kwargs)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/llama_index/llms/google_genai/base.py:360, in GoogleGenAI._chat(self, messages, **kwargs)
#     358 chat = self._client.chats.create(**chat_kwargs)
#     359 try:
# --> 360     response = chat.send_message(
#     361         next_msg.parts if isinstance(next_msg, types.Content) else next_msg
#     362     )
#     363 finally:
#     364     if self.file_mode in ("fileapi", "hybrid"):
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/google/genai/chats.py:252, in Chat.send_message(self, message, config)
#     247   raise ValueError(
#     248       f"Message must be a valid part type: {types.PartUnion} or"
#     249       f" {types.PartUnionDict}, got {type(message)}"
#     250   )
#     251 input_content = t.t_content(message)
# --> 252 response = self._modules.generate_content(
#     253     model=self._model,
#     254     contents=self._curated_history + [input_content],  # type: ignore[arg-type]
#     255     config=config if config else self._config,
#     256 )
#     257 model_output = (
#     258     [response.candidates[0].content]
#     259     if response.candidates and response.candidates[0].content
#     260     else []
#     261 )
#     262 automatic_function_calling_history = (
#     263     response.automatic_function_calling_history
#     264     if response.automatic_function_calling_history
#     265     else []
#     266 )
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/google/genai/models.py:6331, in Models.generate_content(self, model, contents, config)
#    6329 while remaining_remote_calls_afc > 0:
#    6330   i += 1
# -> 6331   response = self._generate_content(
#    6332       model=model, contents=contents, config=parsed_config
#    6333   )
#    6335   function_map = _extra_utils.get_function_map(parsed_config)
#    6336   if not function_map:
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/google/genai/models.py:4767, in Models._generate_content(self, model, contents, config)
#    4764 request_dict = _common.convert_to_dict(request_dict)
#    4765 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4767 response = self._api_client.request(
#    4768     'post', path, request_dict, http_options
#    4769 )
#    4771 if config is not None and getattr(
#    4772     config, 'should_return_http_response', None
#    4773 ):
#    4774   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/google/genai/_api_client.py:1605, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1595 def request(
#    1596     self,
#    1597     http_method: str,
#    (...)   1600     http_options: Optional[HttpOptionsOrDict] = None,
#    1601 ) -> SdkHttpResponse:
#    1602   http_request = self._build_request(
#    1603       http_method, path, request_dict, http_options
#    1604   )
# -> 1605   response = self._request(http_request, http_options, stream=False)
#    1606   response_body = (
#    1607       response.response_stream[0] if response.response_stream else ''
#    1608   )
#    1609   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/google/genai/_api_client.py:1398, in BaseApiClient._request(self, http_request, http_options, stream)
#    1395     retry = tenacity.Retrying(**retry_kwargs)
#    1396     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1398 return self._retry(self._request_once, http_request, stream)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/google/genai/_api_client.py:1375, in BaseApiClient._request_once(self, http_request, stream)
#    1367   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1368       method=http_request.method,
#    1369       url=http_request.url,
#    (...)   1372       timeout=http_request.timeout,
#    1373   )
#    1374   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1375 errors.APIError.raise_for_response(response)
#    1376 return HttpResponse(
#    1377     response.headers, response if stream else [response.text]
#    1378 )
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/google/genai/errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File ~/Downloads/GenAIByKrishNaik/GenAI/myvenv/lib/python3.12/site-packages/google/genai/errors.py:186, in APIError.raise_error(cls, status_code, response_json, response)
#     184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
# --> 186   raise ServerError(status_code, response_json, response)
#     187 else:
#     188   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
from llama_index.core.llms import ChatMessage
from llama_index.llms.google_genai import GoogleGenAI

messages = [
    ChatMessage(
        role="system", content="You are a pirate with colorful personality"
    ),
    ChatMessage(
        role="user", content="Tell me a story"
    )
]
llm = GoogleGenAI(model = "gemini-2.5-flash")
response = llm.chat(messages)
print(response)
# Out:
# assistant: Ahoy there, matey! Pull up a barrel, or I'll make ye walk the plank for standin' idle! Ye want a story, eh? Well, ol' Captain Blackheart's got more tales than barnacles on a whale's belly, and twice as salty! Settle in, then, and listen close, for this ain't no lullaby for landlubbers.
#
# Let me tell ye 'bout the time we tangled with the **Whispering Reef**, a place where the very ocean tries to steal yer soul... Aye, the very reef that swallowed the *Sea Serpent's Kiss* – my beloved ship, she was – for a whole day and a night!
#
# It was a night much like this, only darker, if ye can imagine! The moon was a sliver, hidin' behind a shroud of clouds, and the waves were whisperin' secrets against the hull of me ship. We were deep in the uncharted waters, chasin' whispers of the legendary **Star-Stone**, a gem said to glow with the light of a thousand suns, hidden somewhere in the treacherous Coral Labyrinth.
#
# My first mate, a scrawny lad named Finn, but with eyes sharper than a cutlass, he was up in the crow's nest. Suddenly, a shriek! Not the wind, mind ye, but Finn's own voice, curdlin' the blood in me veins. "Captain! Below us! The water... it's *singing*!"
#
# I grabbed me spyglass, but there was naught to see but the black, churnin' water. Then, the ship groaned. Not a timber-creak, but a deep, guttural moan, like the very ocean was in pain. The lanterns on deck flickered, then dimmed, one by one, as if somethin' was suckin' the very light out of 'em!
#
# Then it rose. Not a kraken, not a leviathan, but somethin' far more ancient, far more... *wrong*. It was the Whispering Reef itself, matey! Not just coral, but a living, breathing, *singing* mountain of it! It glowed with an eerie, phosphorescent light, and from its myriad nooks and crannies, a thousand voices rose – soft, seductive, like mermaids crooning a death knell. They promised riches, eternal youth, forgotten loves... anything to lure ye closer.
#
# The *Sea Serpent's Kiss* was caught in its grasp, pulled in by an invisible current, drawn towards the glowing, singing maw of the reef. Me crew, brave as they were, they were frozen, their faces pale as a ghost's backside. Their eyes glazed over, lost in the siren song, their hands slack on the ropes. Even I felt a strange pull, a longing for somethin' I couldn't name, a warmth that promised peace... and oblivion.
#
# "Snap out of it, ye scurvy dogs!" I roared, tryin' to break the spell. "It's a trick! A trap! The reef feeds on yer dreams, then yer bones!" But me voice was just another whisper against the reef's chorus.
#
# We were doomed, I thought. This was it. The end of Captain Blackheart and the *Sea Serpent's Kiss*. But then, a glint in me eye, a spark of an idea! Not a cannon, not a sword... but somethin' else!
#
# "Finn!" I bellowed, pointin' to the ship's galley. "Bring every bell, every drum, every blasted pot and pan ye can find! And the cook's rum! All of it!"
#
# The crew looked at me like I'd finally gone mad, but a few, those with stronger wills or perhaps just more rum in their bellies, started to stir. We gathered every noisy thing we had, every drop of flammable liquid. And then, with a mighty heave, we started a racket!
#
# *CLANG! BANG! CRASH!* We beat the drums, rang the bells, hammered on pots and pans! The cook, bless his drunken heart, even started singin' a bawdy sea shanty at the top of his lungs, off-key and full of fire! The rum, we poured it over the deck and lit it, creatin' a wall of flame that crackled and roared!
#
# The noise, the fire, the sheer *discord*! It was poison to the reef's sweet song! The Whispering Reef recoiled! Its eerie glow flickered, its voices turned to shrieks of agony and confusion! The current that held us reversed, pushin' us away from its deadly embrace! It writhed, it twisted, and then, with a final, despairing groan, it sank back into the depths, leavin' naught but a trail of steam and a lingering chill in the air.
#
# We were safe! The moon, as if broken from its own trance, peeked out from behind the clouds, and the lanterns on deck flickered back to their full glory. Me crew cheered, their voices hoarse, their faces streaked with soot and relief.
#
# We never found the Star-Stone that trip, matey. But we found somethin' far more valuable: a tale to tell, and a reminder that even the most beautiful of traps can be broken by a bit of clever thinkin', a whole lot of noise, and maybe, just maybe, a barrel or two of good rum!
#
# So, there ye have it! Now, if ye'll excuse me, this talk of fire and rum has made me thirsty. Another tankard, barkeep! And make it a strong one! Hah!

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="gemma:2b", temperature=0)

response = llm.complete("What is the capital of France?")
print(response)
# Out:
# The capital of France is Paris. It is the political, economic, and cultural center of France.

# %%
from llama_index.core.llms import ChatMessage
from llama_index.llms.ollama import Ollama

llm = Ollama(model="gemma:2b", temperature=0)

messages = [
    ChatMessage(
        role = "system", content = "You are a pirate with a colourful personality"
    ),
    ChatMessage(
        role = "user", content = "Tell me a story"
    ),
] 

response = llm.chat(messages)
print(response)
# Out:
# assistant: A shiver ran down my spine as the salty wind whipped around my face. The sun dipped below the horizon, casting long, eerie shadows on the deck of the ship. My heart hammered against my ribs like a frantic bird trapped in a cage.
#
# "Avast, mateys!" I roared, my voice echoing through the vastness of the night. "The winds be a fickle beast tonight, and we must navigate the treacherous waters with caution."
#
# My crew, a motley bunch of seasoned sailors and fearless buccaneers, gathered around me, their faces grim. We were on a mission, a perilous one, to find the legendary Treasure of Blackbeard. Legends whispered across the ocean, tales of a chest overflowing with gold, jewels, and other precious treasures that would make us rich beyond measure.
#
# As the moon rose, its pale light pierced through the clouds, casting an eerie glow on the deck. We could barely make out the outlines of the ship's rigging, a stark reminder of our precarious position. We had to be nimble, our every move calculated.
#
# We slipped away from the watchful eyes of the Spanish fleet, our sails billowing like the wind itself. We danced through the dark waters, our ship groaning with every turn. The moon became our guide, its eerie glow illuminating hidden coves and revealing the path to our destiny.
#
# Finally, after what felt like an eternity, we stumbled upon a hidden cove. The air around the ship grew thick with anticipation, and the crew erupted in cheers. We had found it, the legendary Blackbeard's treasure.
#
# But as we approached the chest, a sinister gleam appeared in the moon's eyes. It was a map, pointing towards a hidden island shrouded in mist. We had stumbled upon a legend, a tale whispered by the sea itself.
#
# "The treasure of Blackbeard lies not in this chest," I declared, my voice echoing with a sinister tone, "but on that treacherous island, guarded by the Kraken himself!"
#
# The crew erupted in laughter, their eyes gleaming with excitement and fear. We had come too far to turn back now. We had found the Blackbeard we sought, and we were determined to claim his treasure.
#
# And so, the pirate ship, with a crew of seasoned veterans and a thirst for adventure, set sail once more, ready to face the perils that lay ahead.

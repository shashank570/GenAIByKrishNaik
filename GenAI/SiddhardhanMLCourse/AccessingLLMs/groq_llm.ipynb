# %%
# Library -> groq
# groq.com -> sign up using google
# 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
import os
from dotenv import load_dotenv
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
from groq import Groq
client = Groq()
chat_completion = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role" : "system", "content" : "You are a helpful assistant"},
        {"role" : "user", "content" : "What is Deep Learning"}
    ]
) 
print(chat_completion.choices[0].message.content)
# Out:
# **Deep Learning**
#
# Deep learning is a subset of artificial intelligence (AI) that involves the use of neural networks with multiple layers to learn and represent data. These neural networks are modeled after the structure and function of the human brain, with a complex network of interconnected nodes (neurons) that process and transform inputs into outputs.
#
# **Key Characteristics:**
#
# 1. **Multilayer Architecture**: Deep learning models consist of multiple layers of nodes, each of which applies a different set of weights to the input data.
# 2. **Neural Network**: Deep learning models are based on the concept of neural networks, which mimic the way the brain processes information.
# 3. **Training Data**: Deep learning models are trained on large datasets, which are used to adjust the weights and biases of the model.
# 4. **Automatic Feature Learning**: Deep learning models can automatically learn features from raw data, without the need for manual feature extraction.
#
# **Types of Deep Learning:**
#
# 1. **Supervised Learning**: The model is trained on labeled data, where the correct output is provided for each input example.
# 2. **Unsupervised Learning**: The model is trained on unlabeled data, and is used to discover patterns or relationships in the data.
# 3. **Reinforcement Learning**: The model learns through trial and error, by interacting with the environment and receiving feedback.
#
# **Applications of Deep Learning:**
#
# 1. **Image Recognition**: Deep learning is used to recognize objects, scenes, and activities in images.
# 2. **Natural Language Processing (NLP)**: Deep learning is used to analyze and understand human language.
# 3. **Speech Recognition**: Deep learning is used to recognize spoken words and phrases.
# 4. **Robotics**: Deep learning is used to control and navigate robotic systems.
# 5. **Predictive Maintenance**: Deep learning is used to predict when equipment or machinery is likely to fail.
#
# **Key Benefits:**
#
# 1. **Improved Accuracy**: Deep learning models can achieve high accuracy on a wide range of tasks.
# 2. **Increased Efficiency**: Deep learning models can learn from large datasets and automatically adjust their parameters.
# 3. **Flexibility**: Deep learning models can be used for a wide range of tasks, from image recognition to natural language processing.
#
# **Challenges and Limitations:**
#
# 1. **Training Time**: Deep learning models require large amounts of training data and computational resources.
# 2. **Overfitting**: Deep learning models can overfit the training data, leading to poor performance on new, unseen data.
# 3. **Interpretability**: Deep learning models can be difficult to interpret and understand.
#
# **Tools and Software for Deep Learning:**
#
# 1. **TensorFlow**: An open-source software library for deep learning.
# 2. **PyTorch**: An open-source software library for deep learning.
# 3. **Keras**: A high-level neural networks API.
# 4. **OpenCV**: A computer vision library for image and video processing.
#
# **Real-World Examples:**
#
# 1. **Self-Driving Cars**: Deep learning is used to recognize objects, lanes, and road signs in real-time.
# 2. **Chatbots**: Deep learning is used to analyze and understand human language in chatbots.
# 3. **Image Recognition**: Deep learning is used in face recognition, object detection, and image classification.
# 4. **Predictive Maintenance**: Deep learning is used to predict when equipment or machinery is likely to fail.
#
# I hope this helps you understand what Deep Learning is! Let me know if you have any other questions.

# %%
from groq import Groq
client = Groq()
chat_completion = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role" : "system", "content" : "You are a helpful assistant"},
        {"role" : "user", "content" : "What is Deep Learning"},
        {"role" : "assistant", "content" : "Deep learning is a subset of Machine Learning (ML) that utilizes complex neural networks to analyze and learn from data."},
        {"role" : "user", "content" : "Tell me some applications of the same"},
    ]
) 
print(chat_completion.choices[0].message.content)
# Out:
# Here are some applications of Deep Learning:
#
# 1. **Image and Video Recognition**: Facebook uses deep learning to identify objects in images, enabling features like facial recognition and photo tagging. Similarly, Google Photos uses deep learning to identify objects, scenes, and people in images.
# 2. **Speech Recognition**: Virtual assistants like Siri, Alexa, and Google Assistant use deep learning to recognize spoken words and commands.
# 3. **Natural Language Processing (NLP)**: Deep learning is used in text analysis, sentiment analysis, and machine translation. Google's language model, BERT, uses deep learning to improve language understanding.
# 4. **Self-Driving Cars**: Companies like Tesla and Waymo use deep learning to analyze images and sensor data to navigate roads and make driving decisions.
# 5. **Medical Diagnosis**: Deep learning is used in medical imaging to detect diseases like cancer, diabetic retinopathy, and cardiac disease.
# 6. **Predictive Maintenance**: Deep learning is used in manufacturing to predict equipment failure and schedule maintenance, reducing downtime and increasing productivity.
# 7. **Credit Risk Assessment**: Banks and financial institutions use deep learning to analyze creditworthiness and predict loan defaults.
# 8. **Security and Cybersecurity**: Deep learning is used to detect and prevent cyber threats, such as malware and phishing attacks.
# 9. **Recommendation Systems**: Online retailers like Amazon and Netflix use deep learning to recommend products and content to users.
# 10. **Robotics and Autonomous Systems**: Deep learning is used in robotics to enable autonomous navigation, object manipulation, and decision-making.
#
# These are just a few examples of the many applications of deep learning. Its ability to analyze complex data and learn from experience makes it a powerful tool for solving a wide range of problems.

# %%
# Library -> groq
# groq.com -> sign up using google
# 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
import os
os.environ["GROQ_API_KEY"] = "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"

# %%
from groq import Groq
client = Groq()
chat_completion = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role" : "system", "content" : "You are a helpful assistant"},
        {"role" : "user", "content" : "What is Deep Learning"}
    ]
) 
print(chat_completion.choices[0].message.content)
# Out:
# Deep Learning is a subfield of Machine Learning that focuses on artificial neural networks with multiple layers, inspired by the structure and function of the human brain. These networks process and learn complex patterns in data, enabling machines to make decisions, predictions, and classifications.
#
# **Key Characteristics of Deep Learning:**
#
# 1. **Artificial Neural Networks (ANNs)**: Deep Learning models are built using ANNs, which mimic the way the human brain processes information through interconnected nodes (neurons) that receive, transmit, and process signals.
# 2. **Multiple Layers**: Deep Learning models consist of several layers, each with a specific function, such as feature extraction, transformation, and classification.
# 3. **Neural Network Learning**: The model learns by adjusting the weights and biases of the connections between nodes, enabling it to adapt to new data and improve its performance over time.
# ...

# %%
from groq import Groq
client = Groq()
chat_completion = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role" : "system", "content" : "You are a helpful assistant"},
        {"role" : "user", "content" : "What is Deep Learning"},
        {"role" : "assistant", "content" : "Deep learning is a subset of Machine Learning (ML) that utilizes complex neural networks to analyze and learn from data."},
        {"role" : "user", "content" : "Tell me some applications of the same"},
    ]
) 
print(chat_completion.choices[0].message.content)
# Out:
# Deep learning has numerous applications across various industries and fields. Some of the most significant applications include:
#
# 1. **Image Recognition and Classification**: Facebook, Google Photos, and Amazon Rekognition use deep learning for image recognition and classification, enabling features like face tagging, object detection, and automatic tagging of images.
#
# 2. **Natural Language Processing (NLP)**: Companies like Siri, Alexa, and Google Assistant employ deep learning for speech recognition, sentiment analysis, and language translation, making human-computer interaction more natural.
#
# 3. **Self-Driving Cars**: Companies like Waymo, Tesla, and Uber utilize deep learning for image recognition, object detection, and scene understanding, enabling autonomous vehicles to navigate complex traffic scenarios.
#
# ...

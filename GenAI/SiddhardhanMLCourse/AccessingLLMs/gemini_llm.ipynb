# %%
# google-genai library
import os
from dotenv import load_dotenv
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# %%
from google import genai

# %%
client = genai.Client()
response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = "Explain how AI works in few 100 words?"
)

print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Artificial Intelligence (AI) does not "think" the way humans do. Instead, it uses mathematics, massive amounts of data, and high-speed computing to mimic human intelligence. Here is the step-by-step breakdown of how it works:
#
# ### 1. Data: The Fuel
# Everything starts with data. To teach an AI to recognize a cat or write an essay, it must be fed millions of examples. This data (images, text, or numbers) serves as the "textbook" from which the AI learns.
#
# ### 2. Algorithms and Models: The Engine
# An **algorithm** is a set of mathematical instructions. When these algorithms are applied to data, they create a **model**. Think of the model as a complex map of correlations. For example, a model doesn't know what a "dog" is conceptually; it knows that a specific arrangement of pixels usually correlates with the label "dog."
#
# ### 3. Training: The Learning Process
# Most modern AI uses **Machine Learning**. During training, the AI makes a prediction based on its data. If it gets the answer wrong, an optimization process adjusts the model’s internal settings (called "weights") to reduce the error. It repeats this cycle millions of times until its predictions become highly accurate.
#
# ### 4. Neural Networks: The Structure
# The most advanced AI, like ChatGPT or facial recognition, uses **Deep Learning**. This is structured in "neural networks," which are layers of mathematical functions inspired by the human brain. Each layer identifies different features—for instance, the first layer might identify simple lines, while deeper layers recognize shapes, and the final layer recognizes a human face.
#
# ### 5. Inference: The Output
# Once a model is trained, it performs "inference." When you give it a new prompt or image it has never seen before, it uses the patterns it learned during training to calculate the most likely response or classification.
#
# **In short:** AI works by turning information into math, finding patterns in that math, and using those patterns to make a highly educated guess about new information.

# %%
# multi turn conversations (chat)

from google import genai
client = genai.Client()

chat = client.chats.create(model = "gemini-3-flash-preview")

response = chat.send_message("I have 2 dogs in my house")
print(response.text)

print("="*50)

response = chat.send_message("How many paws are in my house?")
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# That sounds like a lot of fun (and probably a lot of energy)! Having two dogs can be a great experience—they often keep each other company and provide double the love.
#
# I'd love to hear more about them!
#
# * **What breeds are they?**
# * **What are their names?**
# * **Do they get along well, or are they a "chaos duo"?**
#
# If you have any questions about managing a multi-dog household—like training tips, feeding schedules, or how to stop them from wrestling in the middle of the night—feel free to ask!
# ==================================================
# There are **8 paws** in your house (assuming both dogs have all four)!
#
# Of course, that doesn't count your own feet—unless you're counting those as "paws" too! 🐾🐾🐾🐾

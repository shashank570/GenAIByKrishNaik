# %%
# google-genai library
import os
os.environ["GEMINI_API_KEY"] = "AQ.Ab8RN6J-XPD5CSknsHTFNEGNHWRndenBO0Ib1hffH73-86xqIQ"

# %%
from google import genai
# Out:
# /Users/shashankshukla/Downloads/GenAIByKrishNaik/GenAI/myenv/lib/python3.9/site-packages/google/auth/__init__.py:54: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# /Users/shashankshukla/Downloads/GenAIByKrishNaik/GenAI/myenv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/shashankshukla/Downloads/GenAIByKrishNaik/GenAI/myenv/lib/python3.9/site-packages/google/oauth2/__init__.py:40: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)

# %%
client = genai.Client()
response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = "Explain how AI works in few 100 words?"
)

print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# At its simplest level, Artificial Intelligence (AI) does not "think" like a human. Instead, it works by identifying complex patterns within massive amounts of data and using those patterns to make predictions or decisions.
#
# Modern AI, particularly **Machine Learning**, operates through three main stages:
#
# ### 1. Data Collection
# Data is the "fuel" for AI. To teach an AI to recognize a cat, you feed it thousands of images labeled "cat" and "not cat." This data can be text, numbers, images, or even sensor readings from a self-driving car.
#
# ### 2. The Training Process
# During training, the AI uses an architecture called a **Neural Network**, which is loosely inspired by the human brain. It consists of layers of mathematical equations (called weights).
# *   The AI makes a guess based on the input data.
# *   It compares its guess to the correct answer.
# *   If it is wrong, an algorithm (called backpropagation) slightly adjusts the internal math to reduce the error.
# *   This cycle repeats millions of times until the system becomes highly accurate.
#
# ### 3. Inference (The Output)
# Once trained, the AI enters the "inference" phase. When you give it a new piece of data it has never seen before, it applies the mathematical patterns it learned during training to provide an answer. For a chatbot like ChatGPT, it isn't "knowing" a fact; it is calculating which word most statistically likely comes next in a sentence based on its training.
#
# ### Summary
# AI is essentially **advanced statistics at scale**. While a human understands that a "chair" is something you sit on, an AI understands a "chair" as a recurring statistical relationship between certain pixels in an image or certain words in a sentence. It turns the messy, qualitative world into quantitative math, allowing it to solve problems, generate art, or drive cars with superhuman speed and precision.

# %%
# multi turn conversations (chat)

from google import genai
client = genai.Client()

chat = client.chats.create(model = "gemini-3-flash-preview")

response = chat.send_message("I have 2 dogs in my house")
print(response.text)

print("="*50)

response = chat.send_message("How many paws are in my house?")
print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# That sounds like a lot of fun (and probably a lot of energy)!
#
# I'd love to hear more about them.
# *   **What breeds are they?**
# *   **What are their names?**
# *   **Do they get along well, or are they a "dynamic duo" that keeps you on your toes?**
#
# If you have any questions about training, food recommendations, or managing a multi-dog household, feel free to ask!
# ==================================================
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# There are **8 paws** in your house (assuming each dog has all four)!
#
# If you want to count all the "feet" walking around, there are **10** (8 dog paws + your 2 feet).

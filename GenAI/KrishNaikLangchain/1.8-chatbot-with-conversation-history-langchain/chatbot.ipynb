# %%
import os
from dotenv import load_dotenv
load_dotenv()
groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model = "llama-3.1-8b-instant", groq_api_key = groq_api_key)

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="Hi, my name is Shashank and I am a Lead Engineer in NTT Data")])
# Out:
# AIMessage(content="Hello Shashank, nice to meet you. It's great to hear that you're a Lead Engineer at NTT Data. NTT Data is a well-established company with a strong presence in the IT industry. As a Lead Engineer, I assume you have a team of engineers working under you, and you handle various technical projects and tasks.\n\nCould you tell me a bit more about your role and what you enjoy most about working at NTT Data?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 53, 'total_tokens': 145, 'completion_time': 0.158443843, 'completion_tokens_details': None, 'prompt_time': 0.002567305, 'prompt_tokens_details': None, 'queue_time': 0.049738535, 'total_time': 0.161011148}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b6406-1fad-7132-a010-5f88c1c393cb-0', usage_metadata={'input_tokens': 53, 'output_tokens': 92, 'total_tokens': 145})

# %%
model.invoke([HumanMessage(content="What is my name?")])
# Out:
# AIMessage(content="I don't have any information about your name as this is the beginning of our conversation. I'm happy to chat with you and help with any questions you may have, but I don't have any prior knowledge or context about you. Would you like to share your name with me?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 40, 'total_tokens': 98, 'completion_time': 0.075935303, 'completion_tokens_details': None, 'prompt_time': 0.001817922, 'prompt_tokens_details': None, 'queue_time': 0.050540467, 'total_time': 0.077753225}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b6406-2663-7133-b2ee-df86248cf6c5-0', usage_metadata={'input_tokens': 40, 'output_tokens': 58, 'total_tokens': 98})

# %%
from langchain_core.messages import AIMessage
model.invoke(
    [
        HumanMessage(content="Hi, my name is Shashank and I am a Lead Engineer in NTT Data"),
        AIMessage(content="I don't have any information about your name. I'm a large language model, I don't have the ability to retain personal information or recall previous conversations. Each time you interact with me, it's a new conversation. If you'd like to share your name, I'd be happy to chat with you!"),
        HumanMessage(content="What is my name and what do I do?"),
    ]
)
# Out:
# AIMessage(content="You told me earlier that your name is Shashank, and you're a Lead Engineer at NTT Data.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 136, 'total_tokens': 160, 'completion_time': 0.030291278, 'completion_tokens_details': None, 'prompt_time': 0.007595678, 'prompt_tokens_details': None, 'queue_time': 0.056190322, 'total_time': 0.037886956}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b6406-2d2e-7602-8038-f5d42fe80ea7-0', usage_metadata={'input_tokens': 136, 'output_tokens': 24, 'total_tokens': 160})

# %%
## Message History
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

store = {}

# if not exists create a new instance else return the existing one
def get_session_history(session_id:str)->BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

with_message_history = RunnableWithMessageHistory(model, get_session_history)

# %%
config = {"configurable" : {"session_id" : "chat1"}}

# %%
response = with_message_history.invoke(
    [HumanMessage(content="Hi, my name is Shashank and I am Lead Engineer in NTT Data")],
    config = config
)
response
# Out:
# AIMessage(content="Nice to meet you, Shashank. As a Lead Engineer at NTT Data, I'm sure you have a wide range of responsibilities and expertise in your field. What brings you here today? Are you looking for help with a specific project or technology-related question?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 52, 'total_tokens': 107, 'completion_time': 0.078111611, 'completion_tokens_details': None, 'prompt_time': 0.002474077, 'prompt_tokens_details': None, 'queue_time': 0.056243153, 'total_time': 0.080585688}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b6406-4581-7db2-a294-0e411f117c5e-0', usage_metadata={'input_tokens': 52, 'output_tokens': 55, 'total_tokens': 107})

# %%
with_message_history.invoke(
    [HumanMessage(content="What is my name and what i do?")],
    config = config
)
# Out:
# AIMessage(content='Your name is Shashank, and you are a Lead Engineer at NTT Data.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 125, 'total_tokens': 144, 'completion_time': 0.021082289, 'completion_tokens_details': None, 'prompt_time': 0.007101602, 'prompt_tokens_details': None, 'queue_time': 0.050053107, 'total_time': 0.028183891}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b6406-4ddf-7cb1-8d42-07b261ac1eae-0', usage_metadata={'input_tokens': 125, 'output_tokens': 19, 'total_tokens': 144})

# %%
## change the config-->session id
config1 = {"configurable" : {"session_id" : "chat2"}}
with_message_history.invoke(
    [HumanMessage(content="What is my name and what i do?")],
    config = config1
)
# Out:
# AIMessage(content="I don't have any information about your name or what you do. I'm a large language model, I don't have the ability to retain information about individual users or their personal details. Each time you interact with me, it's a new conversation and I don't have any prior knowledge about you.\n\nIf you'd like to share your name and what you do, I'd be happy to chat with you about it!", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 44, 'total_tokens': 130, 'completion_time': 0.096194664, 'completion_tokens_details': None, 'prompt_time': 0.002061444, 'prompt_tokens_details': None, 'queue_time': 0.062634056, 'total_time': 0.098256108}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b6406-5718-7222-9cbf-462f5c1c29af-0', usage_metadata={'input_tokens': 44, 'output_tokens': 86, 'total_tokens': 130})

# %%
with_message_history.invoke(
    [HumanMessage(content="Hey, my name is John")],
    config = config1
)
# Out:
# AIMessage(content="Hello John, it's nice to meet you. I don't know what you do, though. Would you like to share a bit about yourself?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 145, 'total_tokens': 176, 'completion_time': 0.054629642, 'completion_tokens_details': None, 'prompt_time': 0.008074583, 'prompt_tokens_details': None, 'queue_time': 0.055099157, 'total_time': 0.062704225}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b6406-5eec-7903-8c09-0d0e482cae74-0', usage_metadata={'input_tokens': 145, 'output_tokens': 31, 'total_tokens': 176})

# %%
with_message_history.invoke(
    [HumanMessage(content="What is my name?")],
    config = config1
)
# Out:
# AIMessage(content='Your name is John.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 167, 'total_tokens': 173, 'completion_time': 0.009022504, 'completion_tokens_details': None, 'prompt_time': 0.00925781, 'prompt_tokens_details': None, 'queue_time': 0.055280369, 'total_time': 0.018280314}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b63a2-2af3-7103-aa87-db180476b929-0', usage_metadata={'input_tokens': 167, 'output_tokens': 6, 'total_tokens': 173})

# %%
# Prompt Template
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder 
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant. Answer all questions to the best of your ability in {language}."),
        MessagesPlaceholder(variable_name="messages")
    ]
)
chain = prompt | model

# %%
response = chain.invoke(
        {
            "messages" : [HumanMessage(content = "Hi my name is Shashank")],
            "language" : "Hindi"
        }
    )

response.content
# Out:
# 'नमस्ते शशांक जी! मैं आपकी सहायता के लिए यहाँ हूँ। कृपया कोई प्रश्न पूछें या किसी विषय पर चर्चा करने के लिए तैयार रहें।'

# %%
with_message_history=RunnableWithMessageHistory(
    chain,
    get_session_history,
    input_messages_key="messages"
)

config = {"configurable" : {"session_id" : "chat3"}}
with_message_history.invoke(
    {
        "messages" : [HumanMessage(content="Hi, I am Shashank")],
        "language" : "Hindi"
    },
    config = config
)
# Out:
# AIMessage(content='नमस्ते शशांक जी, मैं आपकी सहायता के लिए यहां हूं। क्या आपके पास कोई प्रश्न है या कुछ जानकारी चाहिए?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 60, 'total_tokens': 114, 'completion_time': 0.074823679, 'completion_tokens_details': None, 'prompt_time': 0.003872473, 'prompt_tokens_details': None, 'queue_time': 0.055604327, 'total_time': 0.078696152}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b6407-d304-71e1-9cbb-c68d1d0e4e6b-0', usage_metadata={'input_tokens': 60, 'output_tokens': 54, 'total_tokens': 114})

# %%
with_message_history.invoke(
    {
        "messages" : [HumanMessage(content = "What is my name?")],
        "language" : "Hindi"
    },
    config = config
)
# Out:
# AIMessage(content='आपका नाम शशांक है।', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 154, 'total_tokens': 166, 'completion_time': 0.01030873, 'completion_tokens_details': None, 'prompt_time': 0.010345299, 'prompt_tokens_details': None, 'queue_time': 0.061057561, 'total_time': 0.020654029}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b64fd-b6a2-7ec2-b943-ee105a6ac3d7-0', usage_metadata={'input_tokens': 154, 'output_tokens': 12, 'total_tokens': 166})

# %% [markdown]
# ### Managing the Conversation History
# One important concept to understand when building chatbots is how to manage conversation history. If left unmanaged, the list of messages will grow unbounded and potentially overflow the context window of the LLM. Therefore, it is important to add a step that limits the size of the messages you are passing in.
# 'trim_messages' helper to reduce how many messages we're sending to the model. The trimmer allows us to specify how many tokens we want to keep, along with other parameters like if we want to always keep the system message and whether to allow partial messages

# %%
from langchain_core.messages import SystemMessage, trim_messages
trimmer = trim_messages(
    max_tokens = 70, ## takes only 45 tokens in the message list
    strategy = "last", ## takes the most recent message
    token_counter = model, ## model is used to count tokens
    include_system = True, # always include the system token
    allow_partial = False, 
    start_on = "human" ## always start with human message
)

messages = [
    SystemMessage(content="you're a good assistant"),
    HumanMessage(content="hi! I'm bob"),
    AIMessage(content="hi!"),
    HumanMessage(content="I like vanilla ice cream"),
    AIMessage(content="nice"),
    HumanMessage(content="whats 2 + 2"),
    AIMessage(content="4"),
    HumanMessage(content="thanks"),
    AIMessage(content="no problem!"),
    HumanMessage(content="having fun?"),
    AIMessage(content="yes!"),
]

trimmer.invoke(messages)
# Out:
# [SystemMessage(content="you're a good assistant", additional_kwargs={}, response_metadata={}),
#  HumanMessage(content="hi! I'm bob", additional_kwargs={}, response_metadata={}),
#  AIMessage(content='hi!', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I like vanilla ice cream', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='nice', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='whats 2 + 2', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='4', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='thanks', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='no problem!', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='having fun?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='yes!', additional_kwargs={}, response_metadata={})]

# %%
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough

chain = (
    RunnablePassthrough.assign(messages=itemgetter("messages") | trimmer) 
    | prompt | model
)

chain.invoke(
    {
        "messages" : messages + [HumanMessage(content="What ice creame do i like?")],
        "language" : "English"
    }
)
# Out:
# AIMessage(content='You like vanilla ice cream!', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 146, 'total_tokens': 153, 'completion_time': 0.01671466, 'completion_tokens_details': None, 'prompt_time': 0.009000995, 'prompt_tokens_details': None, 'queue_time': 0.055502915, 'total_time': 0.025715655}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b65a5-f5eb-7531-bc26-09c64b1dce7d-0', usage_metadata={'input_tokens': 146, 'output_tokens': 7, 'total_tokens': 153})

# %%
chain.invoke(
    {
        "messages": messages + [HumanMessage(content="what math problem did i ask")],
        "language": "English",
    }
)
# Out:
# AIMessage(content='You asked 2 + 2.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 144, 'total_tokens': 153, 'completion_time': 0.015917178, 'completion_tokens_details': None, 'prompt_time': 0.009096367, 'prompt_tokens_details': None, 'queue_time': 0.056787483, 'total_time': 0.025013545}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b65a6-0abf-7393-974a-b3e1e2378b38-0', usage_metadata={'input_tokens': 144, 'output_tokens': 9, 'total_tokens': 153})

# %%
with_message_history = RunnableWithMessageHistory(
    chain,
    get_session_history,
    input_messages_key = "messages"
)
config = {"configurable" : {"session_id" : "chat4"}}

# %%
with_message_history.invoke(
    {
        "messages" : messages + [HumanMessage(content="What is my name?")],
        "language" : "Hindi"
    },
    config = config
)
# Out:
# AIMessage(content='तुम्हारा नाम बॉब है!', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 143, 'total_tokens': 157, 'completion_time': 0.027426555, 'completion_tokens_details': None, 'prompt_time': 0.00865902, 'prompt_tokens_details': None, 'queue_time': 0.05507058, 'total_time': 0.036085575}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b65a6-1b7b-7d73-90bc-5117a517f674-0', usage_metadata={'input_tokens': 143, 'output_tokens': 14, 'total_tokens': 157})

# %%
with_message_history.invoke(
    {
        "messages" : messages + [HumanMessage(content="What maths problem did i asked?")],
        "language" : "Hindi"
    },
    config = config
)
# Out:
# AIMessage(content='आपने 2 + 2 जानकारी का प्रश्न पूछा था।', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 145, 'total_tokens': 168, 'completion_time': 0.059382732, 'completion_tokens_details': None, 'prompt_time': 0.008919859, 'prompt_tokens_details': None, 'queue_time': 0.05022561, 'total_time': 0.068302591}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b65a6-5274-78d1-90e7-b28468422cf2-0', usage_metadata={'input_tokens': 145, 'output_tokens': 23, 'total_tokens': 168})

# %%
with_message_history.invoke(
    {
        "messages" : messages + [HumanMessage(content="What flavour ice creame i liked?")],
        "language" : "Hindi"
    },
    config = config
)
# Out:
# AIMessage(content='आपने वैनिला आइस क्रीम पसंद किया था। (You liked vanilla ice cream.)', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 146, 'total_tokens': 173, 'completion_time': 0.060487979, 'completion_tokens_details': None, 'prompt_time': 0.009332457, 'prompt_tokens_details': None, 'queue_time': 0.055380053, 'total_time': 0.069820436}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b65a6-5ca9-7270-9f05-933321e8f56a-0', usage_metadata={'input_tokens': 146, 'output_tokens': 27, 'total_tokens': 173})

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model="llama-3.1-8b-instant", groq_api_key = groq_api_key)
response = model.invoke("What is Groq?")
print(response)
# Out:
# content="Groq is a US-based technology company that specializes in the development of artificial intelligence (AI) acceleration and high-performance computing hardware and software. They primarily focus on creating products that can efficiently process AI workloads, such as those used in natural language processing, computer vision, and deep learning.\n\nGroq's primary product is the Flare chip, a purpose-built AI acceleration chip designed to optimize performance and reduce power consumption for AI workloads. The Flare chip is claimed to achieve higher performance per watt compared to traditional GPU and CPU architectures, making it suitable for applications that require high-speed processing of large amounts of data.\n\nGroq's technologies are being used in various industries, including data centers, cloud computing services, and edge computing applications. They aim to provide AI acceleration solutions that can support the increasing demands of AI workloads while minimizing energy consumption and costs.\n\nIn 2022, Groq secured a large funding round of $300 million from investors, which further solidifies their position in the AI acceleration market." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 204, 'prompt_tokens': 40, 'total_tokens': 244, 'completion_time': 0.364306819, 'completion_tokens_details': None, 'prompt_time': 0.002194496, 'prompt_tokens_details': None, 'queue_time': 0.050803244, 'total_time': 0.366501315}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019b6014-2011-75f1-99fb-c3f06bc543e7-0' usage_metadata={'input_tokens': 40, 'output_tokens': 204, 'total_tokens': 244}

# %%
## we should specify our LLM model, which message is basically provided by the human being, 
## and which message is a kind of instruction to the LLM model.
from langchain_core.messages import HumanMessage, SystemMessage
messages = [
    SystemMessage(content="Translate the following from English to French"),
    HumanMessage(content="Hello, How are you?")
]
result = model.invoke(messages)
result.content ## or we can use StrOutputParser
# Out:
# 'Bonjour, Comment allez-vous ?'

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()
parser.invoke(result)
# Out:
# 'Bonjour, Comment allez-vous ?'

# %%
## Using LCEL we can chain the component
chain = model | parser
chain.invoke(messages)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
from langchain_core.prompts import ChatPromptTemplate
generic_template = "Translate the following into {language}"
prompt = ChatPromptTemplate.from_messages(
    [
        ('system', generic_template),
        ('human', '{text}')
    ]
)

# %%
result=prompt.invoke({"language":"French","text":"Hello"})
result
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following into French', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello', additional_kwargs={}, response_metadata={})])

# %%
chain = prompt | model | parser
chain.invoke({"language":"French","text":"Hello"})
# Out:
# 'Bonjour'
